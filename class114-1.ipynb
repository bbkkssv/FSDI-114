# %% [markdown]
# Start:
# 1. Gather your ingredients:
#    - Get 2 slices of bread
#    - Get a jar of peanut butter
#    - Get a jar of jelly
#    - Get a knife
#    - Get a plate
#
# 2. Check if you have everything:
#    - If anything is missing, stop and go buy it
#
# 3. Set up your workspace:
#    - Place both bread slices on the plate
#
# 4. Apply the peanut butter:
#    - Open the peanut butter jar
#    - Scoop some peanut butter with the knife
#    - Spread it evenly on the first slice of bread
#    - Wipe the knife clean
#    - Close the peanut butter jar
#
# 5. Apply the jelly:
#    - Open the jelly jar
#    - Scoop some jelly with the knife
#    - Spread it evenly on the second slice of bread
#    - Wipe the knife clean
#    - Close the jelly jar
#
# 6. Put the sandwich together:
#    - Flip the second slice over..jelly side down
#    - Place it on top of the first slice
#
#    End

# %% [markdown]
# START
#
# HOW TO FIND THE LARGEST NUMBER IN A LIST:
#
# 1. Check if the list is empty:
#    - If the list has no numbers, stop and say "Error"
#
# 2. Set up a variable to track the largest number:
#    - Take the first number from the list
#    - Call this your "largest number so far"
#
# 3. Compare with all other numbers:
#    - Go through each remaining number in the list one by one
#    - For each number:
#      * Ask: "Is this number bigger than my largest number so far?"
#      * If YES: Replace "largest number so far" with this new number
#      * If NO: Keep your current "largest number so far" and move to the next
#
# 4. When you've checked all numbers:
#    - The "largest number so far" is now the actual largest number
#    - Return this as your answer
#
# END

# %%
def find_largest(number):
    if not number:
        return "Error"
    
    largest_so_far = number[0]
    
    for num in number[1:]:
        if num > largest_so_far:
            largest_so_far = num
    
    return largest_so_far

# %%
numbers = [12, 4, 27, 3, 188, 50, 7]
result = find_largest(numbers)
print("Largest number:", result)
# Out:
# Largest number: 188

# %% [markdown]
# START
#
# COUNT EVEN INT:
#
# 1. Create a counter variable and set it to 0
#
# 2. Go through each number in the list one by one:
#    - For each number:
#      * Check if the number divided by 2 has a remainder of 0 (modulus 0)
#      * If YES (number is even):
#        - Add 1 to the counter
#      * If NO (number is odd):
#        - Do nothing, move to next number
#
# 3. After checking all numbers:
#    - Return the counter
#
# END

# %% [markdown]
# Code- Challenge 4: COunting even numbers

# %%
numbers = [3,4,10,15,999,2]
numbers
# Out:
# [3, 4, 10, 15, 999, 2]

# %%
def count_even_numbers(nums):
    increment = 0
    for num in nums:
        if num % 2 == 0:
            increment += 1
    return increment

numbers = [3,5,27,20,6,3.5,60]
result = count_even_numbers(numbers)
print(result)
# Out:
# 3

# %%
count_even_numbers("string, error")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 count_even_numbers("string, error")
#
# Cell In[13], line 4, in count_even_numbers(nums)
#       2 increment = 0
#       3 for num in nums:
# ----> 4     if num % 2 == 0:
#       5         increment += 1
#       6 return increment
#
# TypeError: not all arguments converted during string formatting
